# %% [markdown]
# ## Exercises
# ## Follow the instructions to recreate the plots using this data:
# ### Data
# #### import numpy as np
# #### x = np.arange(0,100)
# #### y = x*2
# #### z = x**2

# %% [markdown]
# ## Exercise 1
# ### Follow along with these steps:
# #### Create a figure object called fig using plt.figure()
# #### Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# #### Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
x = np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_xlabel('Numbers')
ax.set_ylabel('Numbers * 2')
plt.plot(x,y)

# %% [markdown]
# ## Exercise 2
# ### Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.
# ### Now plot (x,y) on both axes. And call your figure object to show it.

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax1.set_xlabel('Numbers')
ax1.set_ylabel('Numbers * 2')
plt.plot(x,y)
ax2 = fig1.add_axes([0.2,0.5,.2,.2])
ax2.set_xlabel('Numbers')
ax2.set_ylabel('Numbers * 2')
plt.plot(x,y)
fig1.show()

# %% [markdown]
# ## Exercise 3
# ### Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]
# ### Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:

# %%
fig2 = plt.figure()
ax3 = fig2.add_axes([0,0,1,1])
ax3.set_xlabel('Numbers')
ax3.set_ylabel('Numbers * 2')
plt.plot(x,y,z)
ax4 = fig2.add_axes([0.2,0.5,.4,.4])
ax4.set_xlabel('Numbers')
ax4.set_ylabel('Numbers * 2')
plt.plot(x,y,z)
fig2.show()

# %% [markdown]
# ## Exercise 4
# ### Use plt.subplots(nrows=1, ncols=2) to create the plot below.
# ### Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style
# ### See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.

# %%
import matplotlib as mpl
mpl.style.use('seaborn-darkgrid')
print(plt.style.available)

fig3 = plt.figure()
fig3.add_axes()
fig3,axes = plt.subplots(nrows=1,ncols=2,figsize=(15,5))
axes[0,].set_xlabel('Numbers')
axes[0,].set_ylabel('Numbers * 2')
axes[0,].plot(x,y,'c')

axes[1,].set_xlabel('Numbers')
axes[1,].set_ylabel('Numbers Squared')
axes[1,].plot(x,z,'g')
# Out:
# ['seaborn-notebook', 'bmh', 'seaborn-deep', 'fivethirtyeight', '_classic_test', 'seaborn-whitegrid', 'seaborn-muted', 'seaborn-poster', 'seaborn-talk', 'classic', 'seaborn', 'seaborn-colorblind', 'seaborn-bright', 'seaborn-dark', 'seaborn-dark-palette', 'Solarize_Light2', 'fast', 'seaborn-paper', 'grayscale', 'seaborn-ticks', 'seaborn-pastel', 'dark_background', 'seaborn-darkgrid', 'tableau-colorblind10', 'ggplot', 'seaborn-white']
